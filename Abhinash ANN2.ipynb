# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Conv1D, GlobalMaxPooling1D, Embedding
from sklearn.model_selection import cross_val_predict
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score,roc_auc_score,roc_curve
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import matthews_corrcoef
from sklearn import metrics
import warnings
warnings.filterwarnings(action="ignore")

df = pd.read_csv('bank.csv')

strsplit=StratifiedShuffleSplit(n_splits=1, test_size=0.25, random_state=1)

LE=LabelEncoder()
df['deposit']=LE.fit_transform(df.deposit.values)


df=pd.get_dummies(df)
print(df.shape)


for train_index, test_index in strsplit.split(df.drop("deposit",axis=1), df.deposit):
    traindf=df.loc[train_index]
    testdf= df.loc[test_index]


xtrain=traindf.drop('deposit', axis=1)
ytrain=traindf.deposit

xtest=testdf.drop('deposit', axis=1)
ytest=testdf.deposit
print(xtrain.shape)
print(xtest.shape)

scaler = StandardScaler()
xtest = scaler.fit_transform(xtest)
xtrain = scaler.fit_transform(xtrain)

pca = PCA(0.95)
xtrain = pca.fit_transform(xtrain)
xtest = pca.fit_transform(xtest)
print(xtrain.shape)
print(xtest.shape)

model = keras.Sequential(
 [
 keras.layers.Dense(36, activation='relu', input_shape=(36,)),
 keras.layers.Dense(12, activation='relu'),
 keras.layers.Dropout(0.25),
 keras.layers.Dense(1, activation='sigmoid'),
 ]
)

model.compile(
 optimizer=keras.optimizers.Adam(1e-2), 
 loss='binary_crossentropy', 
 metrics=['accuracy']
)

history = model.fit(xtrain,ytrain,batch_size=200,epochs=150,verbose=2,validation_split = 0.25)

plt.plot(history.history['accuracy'], color = 'blue') 
plt.plot(history.history['val_accuracy'], color = 'black')


model = keras.Sequential(
 [
 keras.layers.Dense(36, activation='relu', input_shape=(36,)),
 keras.layers.Dense(18, activation='relu'),
 keras.layers.Dropout(0.25),
 keras.layers.Dense(9, activation='relu'),
 keras.layers.Dropout(0.25),
 keras.layers.Dense(1, activation='sigmoid'),
 ]
)

model.compile(
 optimizer=keras.optimizers.Adam(1e-2), 
 loss='binary_crossentropy', 
 metrics=['accuracy']
)

history = model.fit(xtrain,ytrain,batch_size=200,epochs=150,verbose=2,validation_split = 0.25)
plt.plot(history.history['accuracy'], color = 'orange') 
plt.plot(history.history['val_accuracy'], color = 'red')


model = keras.Sequential(
 [
keras.layers.Dense(36, activation='relu', input_shape=(36,)),
 keras.layers.Dense(24, activation='relu'),
 keras.layers.Dropout(0.25),
 keras.layers.Dense(18, activation='relu'),
 keras.layers.Dropout(0.25),
 keras.layers.Dense(12, activation='relu'),
 keras.layers.Dropout(0.25),
 keras.layers.Dense(1, activation='sigmoid'),
 ]
)

model.compile(
 optimizer=keras.optimizers.Adam(1e-2), 
 loss='binary_crossentropy', 
 metrics=['accuracy']
)

history = model.fit(xtrain,ytrain,batch_size=200,epochs=150,verbose=2,validation_split = 0.25)

plt.plot(history.history['accuracy'], color = 'magenta') 
plt.plot(history.history['val_accuracy'], color = 'green')

plt.title('Accuracy of the models')
plt.ylabel('Accuracy ')
plt.xlabel('Number of Epochs')
plt.legend(['Train1', 'Validation1','Train2', 'Validation2','Train3','Validation3'], loc='best')
plt.show()
# Out:
# (11162, 52)
# (8371, 51)
# (2791, 51)
# (8371, 36)
# (2791, 36)
# Epoch 1/150
# 32/32 - 3s - loss: 0.5468 - accuracy: 0.7179 - val_loss: 0.4280 - val_accuracy: 0.8113 - 3s/epoch - 87ms/step
# Epoch 2/150
# 32/32 - 0s - loss: 0.4103 - accuracy: 0.8262 - val_loss: 0.4025 - val_accuracy: 0.8247 - 80ms/epoch - 2ms/step
# Epoch 3/150
# 32/32 - 0s - loss: 0.3832 - accuracy: 0.8428 - val_loss: 0.3888 - val_accuracy: 0.8290 - 86ms/epoch - 3ms/step
# Epoch 4/150
# 32/32 - 0s - loss: 0.3648 - accuracy: 0.8479 - val_loss: 0.3916 - val_accuracy: 0.8237 - 79ms/epoch - 2ms/step
# Epoch 5/150
# 32/32 - 0s - loss: 0.3594 - accuracy: 0.8507 - val_loss: 0.3860 - val_accuracy: 0.8290 - 72ms/epoch - 2ms/step
# Epoch 6/150
# 32/32 - 0s - loss: 0.3480 - accuracy: 0.8555 - val_loss: 0.3831 - val_accuracy: 0.8323 - 84ms/epoch - 3ms/step
# Epoch 7/150
# 32/32 - 0s - loss: 0.3424 - accuracy: 0.8552 - val_loss: 0.3863 - val_accuracy: 0.8366 - 82ms/epoch - 3ms/step
# Epoch 8/150
# ...
